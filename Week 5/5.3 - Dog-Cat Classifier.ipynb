# %% [markdown]
# # Import Our Data

# %% [markdown]
# Load the data to your Google Drive. Then you can mount your drive and access the folder wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/datasets/dogs-vs-cats"
  
train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 180, 180, 3)]     0
#
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 178, 178, 32)      896
#
#  max_pooling2d (MaxPooling2D  (None, 89, 89, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 87, 87, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 43, 43, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 41, 41, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 20, 20, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 18, 18, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         590080
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 1)                 12545
#
# =================================================================
# Total params: 991,041
# Trainable params: 991,041
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/convnet_from_scratch.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=20,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# 24/24 [==============================] - 5s 175ms/step - loss: 9.2767e-09 - accuracy: 1.0000 - val_loss: 5.4758 - val_accuracy: 0.6925

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we reach > 65% accuracy pretty quickly without much effort, but it plateaus there.

# %%
test_model = keras.models.load_model("convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 126s 3s/step - loss: 0.6488 - accuracy: 0.6566
# Test accuracy: 0.6566416025161743

# %% [markdown]
# # Data Augmentation

# %% [markdown]
# To stave off the overfitting, we will first start by augmenting our dataset. This is a simple way to do it in a Sequential model, by adding a data augmentation layer. This step in our model will randomly mess with the data at each pass, flipping, rotating and zooming each image.

# %%
data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

# %% [markdown]
# You'll see that adding the aaumentation layer gets us another 5% bump in the validation accuracy of our model, up to about 72% fairly consistently. Note that we do a bit worse than the textbook claims, because we are using less data (I kept about 40% of the sample the book was working with).

# %%
from tensorflow import keras 
from tensorflow.keras import layers
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(x)
x = layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.MaxPooling2D(pool_size=2)(x)
x = layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = layers.Flatten()(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# We are making a different callback so we don't overwrite our last model (we might want to compare them)
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="convnet_from_scratch_with_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]

# And let's fit the model.
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 4s 112ms/step - loss: 0.9088 - accuracy: 0.5007 - val_loss: 0.6923 - val_accuracy: 0.5975
# Epoch 2/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.6937 - accuracy: 0.5111 - val_loss: 0.6920 - val_accuracy: 0.5725
# Epoch 3/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.6965 - accuracy: 0.5163 - val_loss: 0.6883 - val_accuracy: 0.5600
# Epoch 4/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.6950 - accuracy: 0.4993 - val_loss: 0.6896 - val_accuracy: 0.5650
# Epoch 5/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.7014 - accuracy: 0.5778 - val_loss: 0.6828 - val_accuracy: 0.5300
# Epoch 6/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.7035 - accuracy: 0.5634 - val_loss: 0.7052 - val_accuracy: 0.5425
# Epoch 7/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6735 - accuracy: 0.5895 - val_loss: 0.6582 - val_accuracy: 0.6250
# Epoch 8/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.6815 - accuracy: 0.6301 - val_loss: 0.6600 - val_accuracy: 0.5725
# Epoch 9/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6558 - accuracy: 0.6458 - val_loss: 0.6451 - val_accuracy: 0.6525
# Epoch 10/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.6470 - accuracy: 0.6209 - val_loss: 0.7151 - val_accuracy: 0.5800
# Epoch 11/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.6229 - accuracy: 0.6575 - val_loss: 0.6280 - val_accuracy: 0.6725
# Epoch 12/100
# 24/24 [==============================] - 3s 101ms/step - loss: 0.6653 - accuracy: 0.6366 - val_loss: 0.6484 - val_accuracy: 0.6550
# Epoch 13/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5936 - accuracy: 0.6680 - val_loss: 0.6242 - val_accuracy: 0.6550
# Epoch 14/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.6476 - accuracy: 0.6993 - val_loss: 0.6120 - val_accuracy: 0.6875
# Epoch 15/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.6206 - accuracy: 0.6902 - val_loss: 0.6725 - val_accuracy: 0.6125
# Epoch 16/100
# 24/24 [==============================] - 3s 107ms/step - loss: 0.5537 - accuracy: 0.7124 - val_loss: 0.9042 - val_accuracy: 0.5725
# Epoch 17/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.5795 - accuracy: 0.7203 - val_loss: 0.5726 - val_accuracy: 0.7050
# Epoch 18/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5499 - accuracy: 0.7216 - val_loss: 0.5487 - val_accuracy: 0.7050
# Epoch 19/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.5269 - accuracy: 0.7333 - val_loss: 0.6475 - val_accuracy: 0.6550
# Epoch 20/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5114 - accuracy: 0.7490 - val_loss: 1.2571 - val_accuracy: 0.5675
# Epoch 21/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.5499 - accuracy: 0.7425 - val_loss: 0.6309 - val_accuracy: 0.7025
# Epoch 22/100
# 24/24 [==============================] - 4s 145ms/step - loss: 0.5295 - accuracy: 0.7307 - val_loss: 0.5980 - val_accuracy: 0.6900
# Epoch 23/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.5240 - accuracy: 0.7464 - val_loss: 0.5928 - val_accuracy: 0.7025
# Epoch 24/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.4988 - accuracy: 0.7647 - val_loss: 0.5197 - val_accuracy: 0.7225
# Epoch 25/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4688 - accuracy: 0.7699 - val_loss: 0.5559 - val_accuracy: 0.7350
# Epoch 26/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4488 - accuracy: 0.7830 - val_loss: 0.7599 - val_accuracy: 0.6225
# Epoch 27/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4613 - accuracy: 0.7791 - val_loss: 0.7257 - val_accuracy: 0.6800
# Epoch 28/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4698 - accuracy: 0.7843 - val_loss: 0.5394 - val_accuracy: 0.7375
# Epoch 29/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.4538 - accuracy: 0.7817 - val_loss: 0.7324 - val_accuracy: 0.6975
# Epoch 30/100
# 24/24 [==============================] - 3s 101ms/step - loss: 0.4578 - accuracy: 0.7660 - val_loss: 0.5457 - val_accuracy: 0.7050
# Epoch 31/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4319 - accuracy: 0.7961 - val_loss: 0.5472 - val_accuracy: 0.7625
# Epoch 32/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4703 - accuracy: 0.7869 - val_loss: 0.8047 - val_accuracy: 0.6675
# Epoch 33/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.4199 - accuracy: 0.8131 - val_loss: 0.7308 - val_accuracy: 0.6700
# Epoch 34/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.4043 - accuracy: 0.8235 - val_loss: 0.6994 - val_accuracy: 0.7450
# Epoch 35/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.4034 - accuracy: 0.8013 - val_loss: 0.5789 - val_accuracy: 0.7375
# Epoch 36/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.4009 - accuracy: 0.8170 - val_loss: 0.5561 - val_accuracy: 0.7525
# Epoch 37/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3774 - accuracy: 0.8405 - val_loss: 0.7278 - val_accuracy: 0.7225
# Epoch 38/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.3839 - accuracy: 0.8248 - val_loss: 0.5441 - val_accuracy: 0.7825
# Epoch 39/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3763 - accuracy: 0.8353 - val_loss: 0.7838 - val_accuracy: 0.7150
# Epoch 40/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3788 - accuracy: 0.8458 - val_loss: 0.7241 - val_accuracy: 0.7300
# Epoch 41/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3625 - accuracy: 0.8327 - val_loss: 0.8241 - val_accuracy: 0.7075
# Epoch 42/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.3490 - accuracy: 0.8458 - val_loss: 0.6608 - val_accuracy: 0.7575
# Epoch 43/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3695 - accuracy: 0.8353 - val_loss: 0.6311 - val_accuracy: 0.7450
# Epoch 44/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.3327 - accuracy: 0.8627 - val_loss: 0.8087 - val_accuracy: 0.6900
# Epoch 45/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.3307 - accuracy: 0.8497 - val_loss: 0.6966 - val_accuracy: 0.7475
# Epoch 46/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.3443 - accuracy: 0.8523 - val_loss: 0.6925 - val_accuracy: 0.7550
# Epoch 47/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2975 - accuracy: 0.8680 - val_loss: 0.7565 - val_accuracy: 0.7450
# Epoch 48/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2868 - accuracy: 0.8863 - val_loss: 0.7204 - val_accuracy: 0.7550
# Epoch 49/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.3179 - accuracy: 0.8510 - val_loss: 0.6619 - val_accuracy: 0.7425
# Epoch 50/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2830 - accuracy: 0.8941 - val_loss: 0.7466 - val_accuracy: 0.7600
# Epoch 51/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2993 - accuracy: 0.8876 - val_loss: 0.7650 - val_accuracy: 0.7300
# Epoch 52/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2820 - accuracy: 0.8915 - val_loss: 0.8603 - val_accuracy: 0.7475
# Epoch 53/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2881 - accuracy: 0.8837 - val_loss: 0.8722 - val_accuracy: 0.7375
# Epoch 54/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2788 - accuracy: 0.8810 - val_loss: 0.6706 - val_accuracy: 0.7525
# Epoch 55/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2948 - accuracy: 0.8797 - val_loss: 0.8898 - val_accuracy: 0.6975
# Epoch 56/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2567 - accuracy: 0.8863 - val_loss: 1.1479 - val_accuracy: 0.6950
# Epoch 57/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.2369 - accuracy: 0.9020 - val_loss: 0.8862 - val_accuracy: 0.7375
# Epoch 58/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2603 - accuracy: 0.8941 - val_loss: 0.9007 - val_accuracy: 0.7450
# Epoch 59/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2439 - accuracy: 0.8967 - val_loss: 1.3014 - val_accuracy: 0.6850
# Epoch 60/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.2860 - accuracy: 0.8837 - val_loss: 0.7471 - val_accuracy: 0.7200
# Epoch 61/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2302 - accuracy: 0.9007 - val_loss: 0.8931 - val_accuracy: 0.7500
# Epoch 62/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2251 - accuracy: 0.9046 - val_loss: 0.8404 - val_accuracy: 0.7750
# Epoch 63/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2470 - accuracy: 0.8993 - val_loss: 0.9828 - val_accuracy: 0.7500
# Epoch 64/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2323 - accuracy: 0.9085 - val_loss: 0.8801 - val_accuracy: 0.7425
# Epoch 65/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.2073 - accuracy: 0.9216 - val_loss: 1.0222 - val_accuracy: 0.7275
# Epoch 66/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.1996 - accuracy: 0.9216 - val_loss: 1.0694 - val_accuracy: 0.7125
# Epoch 67/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2169 - accuracy: 0.9203 - val_loss: 0.9487 - val_accuracy: 0.7300
# Epoch 68/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.2058 - accuracy: 0.9229 - val_loss: 1.0041 - val_accuracy: 0.7600
# Epoch 69/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1910 - accuracy: 0.9307 - val_loss: 0.9936 - val_accuracy: 0.7175
# Epoch 70/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.2135 - accuracy: 0.9072 - val_loss: 1.0429 - val_accuracy: 0.7600
# Epoch 71/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.2160 - accuracy: 0.9229 - val_loss: 0.9721 - val_accuracy: 0.7350
# Epoch 72/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1734 - accuracy: 0.9268 - val_loss: 1.0544 - val_accuracy: 0.7400
# Epoch 73/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1979 - accuracy: 0.9307 - val_loss: 1.1383 - val_accuracy: 0.7100
# Epoch 74/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1754 - accuracy: 0.9203 - val_loss: 0.9403 - val_accuracy: 0.7475
# Epoch 75/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1927 - accuracy: 0.9216 - val_loss: 1.1254 - val_accuracy: 0.7475
# Epoch 76/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1813 - accuracy: 0.9386 - val_loss: 1.0705 - val_accuracy: 0.7325
# Epoch 77/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1777 - accuracy: 0.9307 - val_loss: 0.9777 - val_accuracy: 0.7300
# Epoch 78/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.1517 - accuracy: 0.9359 - val_loss: 1.5367 - val_accuracy: 0.6925
# Epoch 79/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1697 - accuracy: 0.9399 - val_loss: 1.2804 - val_accuracy: 0.6975
# Epoch 80/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1370 - accuracy: 0.9529 - val_loss: 1.3102 - val_accuracy: 0.7075
# Epoch 81/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.1830 - accuracy: 0.9307 - val_loss: 1.1506 - val_accuracy: 0.7500
# Epoch 82/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.1539 - accuracy: 0.9333 - val_loss: 1.3550 - val_accuracy: 0.7225
# Epoch 83/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1684 - accuracy: 0.9307 - val_loss: 1.6422 - val_accuracy: 0.7350
# Epoch 84/100
# 24/24 [==============================] - 4s 142ms/step - loss: 0.1652 - accuracy: 0.9399 - val_loss: 1.0862 - val_accuracy: 0.7250
# Epoch 85/100
# 24/24 [==============================] - 4s 134ms/step - loss: 0.1668 - accuracy: 0.9346 - val_loss: 1.5083 - val_accuracy: 0.7150
# Epoch 86/100
# 24/24 [==============================] - 3s 102ms/step - loss: 0.1008 - accuracy: 0.9621 - val_loss: 1.2973 - val_accuracy: 0.7700
# Epoch 87/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1828 - accuracy: 0.9386 - val_loss: 1.0404 - val_accuracy: 0.7500
# Epoch 88/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1021 - accuracy: 0.9608 - val_loss: 1.2869 - val_accuracy: 0.7375
# Epoch 89/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1635 - accuracy: 0.9425 - val_loss: 1.2246 - val_accuracy: 0.7475
# Epoch 90/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1146 - accuracy: 0.9569 - val_loss: 1.2728 - val_accuracy: 0.7300
# Epoch 91/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1026 - accuracy: 0.9608 - val_loss: 1.9172 - val_accuracy: 0.7075
# Epoch 92/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1906 - accuracy: 0.9373 - val_loss: 1.0281 - val_accuracy: 0.7425
# Epoch 93/100
# 24/24 [==============================] - 3s 106ms/step - loss: 0.0999 - accuracy: 0.9660 - val_loss: 1.2139 - val_accuracy: 0.7600
# Epoch 94/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1578 - accuracy: 0.9503 - val_loss: 1.6405 - val_accuracy: 0.7125
# Epoch 95/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.0853 - accuracy: 0.9739 - val_loss: 1.3171 - val_accuracy: 0.7625
# Epoch 96/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1233 - accuracy: 0.9556 - val_loss: 1.3277 - val_accuracy: 0.7350
# Epoch 97/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1132 - accuracy: 0.9582 - val_loss: 1.4365 - val_accuracy: 0.7525
# Epoch 98/100
# 24/24 [==============================] - 3s 103ms/step - loss: 0.1381 - accuracy: 0.9595 - val_loss: 1.3159 - val_accuracy: 0.7525
# Epoch 99/100
# 24/24 [==============================] - 3s 105ms/step - loss: 0.1349 - accuracy: 0.9569 - val_loss: 1.3236 - val_accuracy: 0.7400
# Epoch 100/100
# 24/24 [==============================] - 3s 104ms/step - loss: 0.1225 - accuracy: 0.9516 - val_loss: 1.3471 - val_accuracy: 0.7475

# %% [markdown]
# Let's plot the accuracy over training again...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And let's check the test accuracy.

# %%
test_model = keras.models.load_model("convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 3s 69ms/step - loss: 0.5933 - accuracy: 0.7206
# Test accuracy: 0.7205513715744019

# %% [markdown]
# # Feature Extraction from a Pre-Trained Model: VGG16

# %% [markdown]
# Now we are going to load a pre-trained model, to leverage its convolutional base for our task. Note that the convolutional base, alone, is about 15 million parameters.

# %%
conv_base = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False, # Throw away the densely connected layer at the end.
    input_shape=(180, 180, 3)) # Optional - just for model.summary() call.

conv_base.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_13 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 180, 180, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 180, 180, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 90, 90, 64)        0
#
#  block2_conv1 (Conv2D)       (None, 90, 90, 128)       73856
#
#  block2_conv2 (Conv2D)       (None, 90, 90, 128)       147584
#
#  block2_pool (MaxPooling2D)  (None, 45, 45, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 45, 45, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 45, 45, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 22, 22, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 22, 22, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 22, 22, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 11, 11, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 11, 11, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 5, 5, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now we run our training, validation, and test data images through the convolutional base, get the feature representations of each according to VGG, and then store them alongside their cat/dog labels.

# %%
import numpy as np
  
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset:
        preprocessed_images = keras.applications.vgg16.preprocess_input(images)
        features = conv_base.predict(preprocessed_images)
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)
  
train_features, train_labels =  get_features_and_labels(train_dataset)
val_features, val_labels =  get_features_and_labels(validation_dataset)
test_features, test_labels =  get_features_and_labels(test_dataset)

# %% [markdown]
# Here, you can see the dimensionality of the features associated with a single image. The VGG output from the convolutional layer comprises of 512 feature-specific feature maps, that are each 5x5 in dimensionality.

# %%
print(train_features[0].shape)
# Out:
# (5, 5, 512)

# %% [markdown]
# So, now we are going to define a new model that sits on the end of the VGG convolutional layer. It'll take those 512 featuremaps, flatten them, pass them to a Dense layer of 256 nodes, and then feed to a one-node sigmoid output (with some Dropout). This model will fit extremely quickly, and it's accuracy will be way higher, approaching 97%

# %%
inputs = keras.Input(shape=(5, 5, 512))
x = layers.Flatten()(inputs)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])
  
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="feature_extraction.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)
# Out:
# Epoch 1/20
# 24/24 [==============================] - 1s 13ms/step - loss: 25.1930 - accuracy: 0.8810 - val_loss: 5.4769 - val_accuracy: 0.9600
# Epoch 2/20
# 24/24 [==============================] - 0s 8ms/step - loss: 2.7703 - accuracy: 0.9791 - val_loss: 5.8123 - val_accuracy: 0.9600
# Epoch 3/20
# 24/24 [==============================] - 0s 6ms/step - loss: 1.2407 - accuracy: 0.9817 - val_loss: 5.5527 - val_accuracy: 0.9600
# Epoch 4/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.5052 - accuracy: 0.9948 - val_loss: 8.7259 - val_accuracy: 0.9550
# Epoch 5/20
# 24/24 [==============================] - 0s 11ms/step - loss: 1.1920 - accuracy: 0.9935 - val_loss: 4.9052 - val_accuracy: 0.9550
# Epoch 6/20
# 24/24 [==============================] - 0s 10ms/step - loss: 0.8607 - accuracy: 0.9908 - val_loss: 4.6634 - val_accuracy: 0.9700
# Epoch 7/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.5127 - accuracy: 0.9948 - val_loss: 5.6984 - val_accuracy: 0.9650
# Epoch 8/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.5872 - accuracy: 0.9961 - val_loss: 8.5425 - val_accuracy: 0.9550
# Epoch 9/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0713 - accuracy: 0.9987 - val_loss: 4.9104 - val_accuracy: 0.9600
# Epoch 10/20
# 24/24 [==============================] - 0s 9ms/step - loss: 0.2049 - accuracy: 0.9974 - val_loss: 4.5458 - val_accuracy: 0.9725
# Epoch 11/20
# 24/24 [==============================] - 0s 7ms/step - loss: 1.9682 - accuracy: 0.9908 - val_loss: 9.9284 - val_accuracy: 0.9525
# Epoch 12/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1473 - accuracy: 0.9974 - val_loss: 11.2511 - val_accuracy: 0.9600
# Epoch 13/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.1075 - accuracy: 0.9987 - val_loss: 7.8836 - val_accuracy: 0.9500
# Epoch 14/20
# 24/24 [==============================] - 0s 6ms/step - loss: 0.4618 - accuracy: 0.9974 - val_loss: 6.8541 - val_accuracy: 0.9475
# Epoch 15/20
# 24/24 [==============================] - 0s 6ms/step - loss: 1.6632e-22 - accuracy: 1.0000 - val_loss: 6.8541 - val_accuracy: 0.9475
# Epoch 16/20
# 24/24 [==============================] - 0s 7ms/step - loss: 7.3734e-14 - accuracy: 1.0000 - val_loss: 6.8541 - val_accuracy: 0.9475
# Epoch 17/20
# 24/24 [==============================] - 0s 5ms/step - loss: 0.1236 - accuracy: 0.9987 - val_loss: 14.8030 - val_accuracy: 0.9550
# Epoch 18/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0452 - accuracy: 0.9974 - val_loss: 9.7603 - val_accuracy: 0.9575
# Epoch 19/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7603 - val_accuracy: 0.9575
# Epoch 20/20
# 24/24 [==============================] - 0s 7ms/step - loss: 0.0000e+00 - accuracy: 1.0000 - val_loss: 9.7603 - val_accuracy: 0.9575

# %% [markdown]
# Plotting performance here...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# And, evaluating performance on the test data.

# %%
test_model = keras.models.load_model("feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features,test_labels) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 0s 4ms/step - loss: 7.7189 - accuracy: 0.9574
# Test accuracy: 0.9573934674263

# %% [markdown]
# # Fine-Tuning from a Pre-Trained Model (with Data-Augmentation)

# %% [markdown]
# Here we are going to load the convolutional base, and actually use it inside our network (though we will freeze its parameters so we don't try to update them as we go, since that would ruin the model and add lots of computation time).

# %%
conv_base  = keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False)
conv_base.trainable = False # The convolutional layers won't be updatable; we just build on them using Functional API.

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])
  
inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = keras.applications.vgg16.preprocess_input(x)
x = conv_base(x)
x = layers.Flatten()(x)
x = layers.Dense(256)(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs, outputs)
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

model.summary()
# Out:
# Model: "model_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_17 (InputLayer)       [(None, 180, 180, 3)]     0
#
#  sequential_2 (Sequential)   (None, 180, 180, 3)       0
#
#  tf.__operators__.getitem (S  (None, 180, 180, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 180, 180, 3)      0
#
#  vgg16 (Functional)          (None, None, None, 512)   14714688
#
#  flatten_8 (Flatten)         (None, 12800)             0
#
#  dense_9 (Dense)             (None, 256)               3277056
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_10 (Dense)            (None, 1)                 257
#
# =================================================================
# Total params: 17,992,001
# Trainable params: 3,277,313
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# And now we can fit our model. This is slower because our forward pass has to go through the VGG convolutional base each iteration (rather than the one time we did when we used it for feature extraction.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="fine_tuning_with_data_augmentation.keras",
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset, # Note we are back to working with our original training dataset.
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/50
# 24/24 [==============================] - 5s 142ms/step - loss: 23.6786 - accuracy: 0.8601 - val_loss: 16.7851 - val_accuracy: 0.9100
# Epoch 2/50
# 24/24 [==============================] - 4s 139ms/step - loss: 4.4057 - accuracy: 0.9647 - val_loss: 6.5353 - val_accuracy: 0.9425
# Epoch 3/50
# 24/24 [==============================] - 4s 128ms/step - loss: 8.4143 - accuracy: 0.9503 - val_loss: 12.7261 - val_accuracy: 0.9300
# Epoch 4/50
# 24/24 [==============================] - 4s 130ms/step - loss: 5.2881 - accuracy: 0.9595 - val_loss: 11.1891 - val_accuracy: 0.9375
# Epoch 5/50
# 24/24 [==============================] - 4s 129ms/step - loss: 3.7171 - accuracy: 0.9686 - val_loss: 9.5395 - val_accuracy: 0.9575
# Epoch 6/50
# 24/24 [==============================] - 4s 128ms/step - loss: 5.5951 - accuracy: 0.9582 - val_loss: 9.2204 - val_accuracy: 0.9600
# Epoch 7/50
# 24/24 [==============================] - 4s 128ms/step - loss: 4.1207 - accuracy: 0.9660 - val_loss: 8.0456 - val_accuracy: 0.9450
# Epoch 8/50
# 24/24 [==============================] - 4s 130ms/step - loss: 2.6356 - accuracy: 0.9765 - val_loss: 17.7459 - val_accuracy: 0.9425
# Epoch 9/50
# 24/24 [==============================] - 4s 128ms/step - loss: 2.3155 - accuracy: 0.9765 - val_loss: 8.3263 - val_accuracy: 0.9500
# Epoch 10/50
# 24/24 [==============================] - 4s 128ms/step - loss: 1.9232 - accuracy: 0.9804 - val_loss: 11.9682 - val_accuracy: 0.9450
# Epoch 11/50
# 24/24 [==============================] - 4s 130ms/step - loss: 1.4340 - accuracy: 0.9830 - val_loss: 7.9574 - val_accuracy: 0.9500
# Epoch 12/50
# 24/24 [==============================] - 4s 131ms/step - loss: 2.4169 - accuracy: 0.9765 - val_loss: 12.3837 - val_accuracy: 0.9475
# Epoch 13/50
# 24/24 [==============================] - 4s 129ms/step - loss: 3.6870 - accuracy: 0.9765 - val_loss: 12.0364 - val_accuracy: 0.9400
# Epoch 14/50
# 24/24 [==============================] - 4s 128ms/step - loss: 1.5295 - accuracy: 0.9882 - val_loss: 11.0868 - val_accuracy: 0.9450
# Epoch 15/50
# 24/24 [==============================] - 4s 128ms/step - loss: 3.3445 - accuracy: 0.9791 - val_loss: 15.3169 - val_accuracy: 0.9250
# Epoch 16/50
# 24/24 [==============================] - 4s 128ms/step - loss: 1.6459 - accuracy: 0.9830 - val_loss: 11.9056 - val_accuracy: 0.9375
# Epoch 17/50
# 24/24 [==============================] - 4s 129ms/step - loss: 2.4654 - accuracy: 0.9817 - val_loss: 8.5582 - val_accuracy: 0.9575
# Epoch 18/50
# 24/24 [==============================] - 4s 140ms/step - loss: 2.0037 - accuracy: 0.9817 - val_loss: 6.3869 - val_accuracy: 0.9575
# Epoch 19/50
# 24/24 [==============================] - 4s 152ms/step - loss: 1.2051 - accuracy: 0.9869 - val_loss: 8.6161 - val_accuracy: 0.9500
# Epoch 20/50
# 24/24 [==============================] - 4s 130ms/step - loss: 1.0706 - accuracy: 0.9895 - val_loss: 10.0113 - val_accuracy: 0.9475
# Epoch 21/50
# 24/24 [==============================] - 4s 129ms/step - loss: 1.3050 - accuracy: 0.9869 - val_loss: 10.4261 - val_accuracy: 0.9425
# Epoch 22/50
# 24/24 [==============================] - 4s 130ms/step - loss: 0.7349 - accuracy: 0.9922 - val_loss: 15.3854 - val_accuracy: 0.9475
# Epoch 23/50
# 24/24 [==============================] - 4s 128ms/step - loss: 0.9553 - accuracy: 0.9882 - val_loss: 10.8298 - val_accuracy: 0.9525
# Epoch 24/50
# 24/24 [==============================] - 4s 128ms/step - loss: 1.1811 - accuracy: 0.9882 - val_loss: 7.6092 - val_accuracy: 0.9625
# Epoch 25/50
# 24/24 [==============================] - 4s 130ms/step - loss: 0.9689 - accuracy: 0.9922 - val_loss: 7.6343 - val_accuracy: 0.9600
# Epoch 26/50
# 24/24 [==============================] - 4s 130ms/step - loss: 1.6674 - accuracy: 0.9843 - val_loss: 11.9683 - val_accuracy: 0.9550
# Epoch 27/50
# 24/24 [==============================] - 4s 131ms/step - loss: 1.2176 - accuracy: 0.9908 - val_loss: 15.1568 - val_accuracy: 0.9450
# Epoch 28/50
# 24/24 [==============================] - 4s 133ms/step - loss: 0.9248 - accuracy: 0.9922 - val_loss: 11.7220 - val_accuracy: 0.9450
# Epoch 29/50
# 24/24 [==============================] - 4s 130ms/step - loss: 0.2622 - accuracy: 0.9961 - val_loss: 9.0827 - val_accuracy: 0.9600
# Epoch 30/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.8380 - accuracy: 0.9882 - val_loss: 14.1492 - val_accuracy: 0.9425
# Epoch 31/50
# 24/24 [==============================] - 4s 132ms/step - loss: 1.0464 - accuracy: 0.9908 - val_loss: 11.1760 - val_accuracy: 0.9525
# Epoch 32/50
# 24/24 [==============================] - 4s 128ms/step - loss: 0.8400 - accuracy: 0.9895 - val_loss: 23.5358 - val_accuracy: 0.9425
# Epoch 33/50
# 24/24 [==============================] - 4s 131ms/step - loss: 1.4809 - accuracy: 0.9830 - val_loss: 10.0905 - val_accuracy: 0.9500
# Epoch 34/50
# 24/24 [==============================] - 4s 132ms/step - loss: 1.1472 - accuracy: 0.9895 - val_loss: 10.1133 - val_accuracy: 0.9500
# Epoch 35/50
# 24/24 [==============================] - 4s 130ms/step - loss: 1.5602 - accuracy: 0.9908 - val_loss: 8.5339 - val_accuracy: 0.9575
# Epoch 36/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.4582 - accuracy: 0.9948 - val_loss: 9.2209 - val_accuracy: 0.9550
# Epoch 37/50
# 24/24 [==============================] - 4s 129ms/step - loss: 0.8208 - accuracy: 0.9895 - val_loss: 10.5857 - val_accuracy: 0.9625
# Epoch 38/50
# 24/24 [==============================] - 4s 129ms/step - loss: 1.5390 - accuracy: 0.9895 - val_loss: 9.1411 - val_accuracy: 0.9600
# Epoch 39/50
# 24/24 [==============================] - 4s 129ms/step - loss: 0.7681 - accuracy: 0.9948 - val_loss: 10.2644 - val_accuracy: 0.9525
# Epoch 40/50
# 24/24 [==============================] - 4s 128ms/step - loss: 1.0030 - accuracy: 0.9922 - val_loss: 12.5450 - val_accuracy: 0.9575
# Epoch 41/50
# 24/24 [==============================] - 4s 130ms/step - loss: 0.0386 - accuracy: 0.9974 - val_loss: 11.7579 - val_accuracy: 0.9500
# Epoch 42/50
# 24/24 [==============================] - 4s 129ms/step - loss: 0.5132 - accuracy: 0.9961 - val_loss: 10.7739 - val_accuracy: 0.9550
# Epoch 43/50
# 24/24 [==============================] - 4s 131ms/step - loss: 8.6228e-08 - accuracy: 1.0000 - val_loss: 10.7637 - val_accuracy: 0.9550
# Epoch 44/50
# 24/24 [==============================] - 4s 132ms/step - loss: 0.3574 - accuracy: 0.9922 - val_loss: 15.3211 - val_accuracy: 0.9575
# Epoch 45/50
# 24/24 [==============================] - 4s 130ms/step - loss: 0.4647 - accuracy: 0.9908 - val_loss: 12.1905 - val_accuracy: 0.9550
# Epoch 46/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.2380 - accuracy: 0.9948 - val_loss: 11.3197 - val_accuracy: 0.9575
# Epoch 47/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.5723 - accuracy: 0.9935 - val_loss: 12.7132 - val_accuracy: 0.9500
# Epoch 48/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.4209 - accuracy: 0.9935 - val_loss: 12.9064 - val_accuracy: 0.9550
# Epoch 49/50
# 24/24 [==============================] - 4s 131ms/step - loss: 0.6163 - accuracy: 0.9948 - val_loss: 10.6553 - val_accuracy: 0.9625
# Epoch 50/50
# 24/24 [==============================] - 4s 132ms/step - loss: 0.1906 - accuracy: 0.9961 - val_loss: 14.1847 - val_accuracy: 0.9525
