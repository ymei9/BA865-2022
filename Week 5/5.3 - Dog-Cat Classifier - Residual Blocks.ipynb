# %% [markdown]
# # Import Our Data

# %% [markdown]
# Save the data to your Google Drive. Then you can mount your drive and access the folder from wherever you saved it.

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Here, we are using the image_dataset_from_directory utilty, which reads images from a file path into a tf.Dataset object. This is much more memory efficient than reading images into lists! The dataset is already organized into training, test, and validation splits on my file system. The labels are inferred from the folder names.

# %%
from tensorflow.keras.utils import image_dataset_from_directory

base_dir = "drive/My Drive/Teaching/Courses/BA 865/BA865-2022/Week 5/datasets/dogs-vs-cats"
  
train_dataset = image_dataset_from_directory(
    base_dir + "/train/",
    image_size=(180, 180),
    batch_size=32)
validation_dataset = image_dataset_from_directory(
    base_dir + "/validation/",
    image_size=(180, 180),
    batch_size=32)
test_dataset = image_dataset_from_directory(
    base_dir + "/test/",
    image_size=(180, 180),
    batch_size=32)
# Out:
# Found 765 files belonging to 2 classes.
# Found 400 files belonging to 2 classes.
# Found 798 files belonging to 2 classes.

# %%
for data_batch, labels_batch in train_dataset:
     print("data batch shape:", data_batch.shape)
     print("labels batch shape:", labels_batch.shape)
     break
# Out:
# data batch shape: (32, 180, 180, 3)
# labels batch shape: (32,)

# %% [markdown]
# # Define Our Model

# %%
from tensorflow import keras 
from tensorflow.keras import layers

data_augmentation = keras.Sequential([
   layers.RandomFlip("horizontal"),
   layers.RandomRotation(0.1),
   layers.RandomZoom(0.2),
])

inputs = keras.Input(shape=(180, 180, 3))
x = data_augmentation(inputs)
x = layers.Rescaling(1./255)(inputs)
x = layers.Conv2D(filters=32, kernel_size=5, use_bias=False)(x)
 
for size in [32, 64, 128]:
    residual = x
 
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(size, 3, padding="same", use_bias=False)(x)
  
    x = layers.BatchNormalization()(x)
    x = layers.Activation("relu")(x)
    x = layers.Conv2D(size, 3, padding="same", use_bias=False)(x)
  
    x = layers.MaxPooling2D(3, strides=2, padding="same")(x)
  
    residual = layers.Conv2D(size, 1, strides=2, padding="same", use_bias=False)(residual)
    x = layers.add([x, residual])
  
x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.5)(x)
outputs = layers.Dense(1, activation="sigmoid")(x)
model = keras.Model(inputs=inputs, outputs=outputs)

keras.utils.plot_model(model,show_shapes=True)

# %% [markdown]
# We have a binary outcome variable, hence our use of Sigmoid activation on the output layer. We will use binary cross-entropy loss as our loss function. And, we'll monitor accuracy.

# %%
model.compile(loss="binary_crossentropy",
              optimizer="rmsprop",
              metrics=["accuracy"])

# %% [markdown]
# This callback we are defining will write the current best model (and parameter values) to disk, based on minimum validation loss.

# %%
callbacks = [
    keras.callbacks.ModelCheckpoint(
        filepath="Xception.keras",
        save_best_only=True,
        monitor="val_loss")
]

# %% [markdown]
# Note that batch size isn't defined here, because we defined it when we first created the tf.Dataset object! This Dataset object is an iterator, containing batches of images.

# %%
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
# Out:
# Epoch 1/100
# 24/24 [==============================] - 7s 147ms/step - loss: 1.6479 - accuracy: 0.5686 - val_loss: 0.6959 - val_accuracy: 0.5075
# Epoch 2/100
# 24/24 [==============================] - 4s 129ms/step - loss: 1.0243 - accuracy: 0.5307 - val_loss: 0.6966 - val_accuracy: 0.5050
# Epoch 3/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.9031 - accuracy: 0.5634 - val_loss: 0.6993 - val_accuracy: 0.5125
# Epoch 4/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.7982 - accuracy: 0.5778 - val_loss: 0.7004 - val_accuracy: 0.4875
# Epoch 5/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.8142 - accuracy: 0.5843 - val_loss: 0.8026 - val_accuracy: 0.5025
# Epoch 6/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.8063 - accuracy: 0.5856 - val_loss: 0.7937 - val_accuracy: 0.5000
# Epoch 7/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.7314 - accuracy: 0.5935 - val_loss: 1.0358 - val_accuracy: 0.5175
# Epoch 8/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.8048 - accuracy: 0.6065 - val_loss: 0.7829 - val_accuracy: 0.5175
# Epoch 9/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.7727 - accuracy: 0.6052 - val_loss: 0.8870 - val_accuracy: 0.5075
# Epoch 10/100
# 24/24 [==============================] - 4s 131ms/step - loss: 0.7678 - accuracy: 0.6157 - val_loss: 0.7010 - val_accuracy: 0.5300
# Epoch 11/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.7213 - accuracy: 0.6222 - val_loss: 0.9285 - val_accuracy: 0.5100
# Epoch 12/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.6488 - accuracy: 0.6536 - val_loss: 0.7039 - val_accuracy: 0.5550
# Epoch 13/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.7208 - accuracy: 0.6471 - val_loss: 0.7608 - val_accuracy: 0.5150
# Epoch 14/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.6359 - accuracy: 0.6536 - val_loss: 0.9244 - val_accuracy: 0.5450
# Epoch 15/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.6863 - accuracy: 0.6261 - val_loss: 0.8775 - val_accuracy: 0.5125
# Epoch 16/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.6333 - accuracy: 0.6824 - val_loss: 0.7386 - val_accuracy: 0.5975
# Epoch 17/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.6176 - accuracy: 0.6797 - val_loss: 0.7256 - val_accuracy: 0.5950
# Epoch 18/100
# 24/24 [==============================] - 4s 131ms/step - loss: 0.6068 - accuracy: 0.7007 - val_loss: 0.8591 - val_accuracy: 0.6100
# Epoch 19/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5942 - accuracy: 0.6837 - val_loss: 1.0834 - val_accuracy: 0.5675
# Epoch 20/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.5859 - accuracy: 0.6902 - val_loss: 0.9168 - val_accuracy: 0.5850
# Epoch 21/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.5804 - accuracy: 0.7046 - val_loss: 0.9035 - val_accuracy: 0.5725
# Epoch 22/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5789 - accuracy: 0.7190 - val_loss: 0.6979 - val_accuracy: 0.6000
# Epoch 23/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.5677 - accuracy: 0.7124 - val_loss: 0.6570 - val_accuracy: 0.6300
# Epoch 24/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5739 - accuracy: 0.7333 - val_loss: 0.6499 - val_accuracy: 0.6450
# Epoch 25/100
# 24/24 [==============================] - 4s 132ms/step - loss: 0.5472 - accuracy: 0.7281 - val_loss: 0.7504 - val_accuracy: 0.6575
# Epoch 26/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.5382 - accuracy: 0.7307 - val_loss: 0.6251 - val_accuracy: 0.6775
# Epoch 27/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.5499 - accuracy: 0.7268 - val_loss: 0.9711 - val_accuracy: 0.5225
# Epoch 28/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.5216 - accuracy: 0.7373 - val_loss: 0.7098 - val_accuracy: 0.6300
# Epoch 29/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5039 - accuracy: 0.7647 - val_loss: 2.3208 - val_accuracy: 0.5025
# Epoch 30/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5418 - accuracy: 0.7255 - val_loss: 1.0924 - val_accuracy: 0.5775
# Epoch 31/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.5033 - accuracy: 0.7412 - val_loss: 0.6674 - val_accuracy: 0.6875
# Epoch 32/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.4931 - accuracy: 0.7725 - val_loss: 0.6328 - val_accuracy: 0.6550
# Epoch 33/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.4983 - accuracy: 0.7621 - val_loss: 0.6133 - val_accuracy: 0.6800
# Epoch 34/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.4977 - accuracy: 0.7686 - val_loss: 0.7837 - val_accuracy: 0.5875
# Epoch 35/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.4868 - accuracy: 0.7804 - val_loss: 0.7504 - val_accuracy: 0.6475
# Epoch 36/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.4617 - accuracy: 0.7882 - val_loss: 1.0427 - val_accuracy: 0.6175
# Epoch 37/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.4586 - accuracy: 0.7869 - val_loss: 1.2700 - val_accuracy: 0.6000
# Epoch 38/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.4708 - accuracy: 0.7830 - val_loss: 3.6338 - val_accuracy: 0.5000
# Epoch 39/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.4662 - accuracy: 0.7856 - val_loss: 0.9978 - val_accuracy: 0.6475
# Epoch 40/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.4407 - accuracy: 0.7948 - val_loss: 0.7904 - val_accuracy: 0.6725
# Epoch 41/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.4248 - accuracy: 0.8039 - val_loss: 1.0216 - val_accuracy: 0.6025
# Epoch 42/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.4220 - accuracy: 0.8000 - val_loss: 0.8692 - val_accuracy: 0.6350
# Epoch 43/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.4162 - accuracy: 0.8144 - val_loss: 0.9311 - val_accuracy: 0.6175
# Epoch 44/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.4162 - accuracy: 0.8065 - val_loss: 1.3982 - val_accuracy: 0.5500
# Epoch 45/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.3927 - accuracy: 0.8235 - val_loss: 0.8916 - val_accuracy: 0.6275
# Epoch 46/100
# 24/24 [==============================] - 4s 131ms/step - loss: 0.3616 - accuracy: 0.8444 - val_loss: 0.8126 - val_accuracy: 0.6575
# Epoch 47/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.3905 - accuracy: 0.8379 - val_loss: 0.9935 - val_accuracy: 0.5775
# Epoch 48/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.3636 - accuracy: 0.8431 - val_loss: 2.2470 - val_accuracy: 0.5975
# Epoch 49/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.3826 - accuracy: 0.8288 - val_loss: 0.6230 - val_accuracy: 0.6550
# Epoch 50/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.3680 - accuracy: 0.8458 - val_loss: 1.8399 - val_accuracy: 0.5525
# Epoch 51/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.3566 - accuracy: 0.8562 - val_loss: 0.8784 - val_accuracy: 0.6775
# Epoch 52/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.3292 - accuracy: 0.8601 - val_loss: 5.3879 - val_accuracy: 0.5250
# Epoch 53/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.3437 - accuracy: 0.8510 - val_loss: 1.7958 - val_accuracy: 0.5625
# Epoch 54/100
# 24/24 [==============================] - 4s 132ms/step - loss: 0.2998 - accuracy: 0.8680 - val_loss: 1.4000 - val_accuracy: 0.6325
# Epoch 55/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.3030 - accuracy: 0.8758 - val_loss: 5.1963 - val_accuracy: 0.5475
# Epoch 56/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.3268 - accuracy: 0.8523 - val_loss: 2.2677 - val_accuracy: 0.5575
# Epoch 57/100
# 24/24 [==============================] - 4s 126ms/step - loss: 0.2956 - accuracy: 0.8850 - val_loss: 1.2657 - val_accuracy: 0.6775
# Epoch 58/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.2537 - accuracy: 0.9072 - val_loss: 2.5807 - val_accuracy: 0.5975
# Epoch 59/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.3015 - accuracy: 0.8719 - val_loss: 1.1922 - val_accuracy: 0.6550
# Epoch 60/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.2691 - accuracy: 0.8824 - val_loss: 1.0301 - val_accuracy: 0.6475
# Epoch 61/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.2567 - accuracy: 0.8928 - val_loss: 0.9839 - val_accuracy: 0.7275
# Epoch 62/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.3202 - accuracy: 0.8667 - val_loss: 1.8073 - val_accuracy: 0.6450
# Epoch 63/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.2422 - accuracy: 0.9242 - val_loss: 1.2643 - val_accuracy: 0.6650
# Epoch 64/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.2727 - accuracy: 0.8850 - val_loss: 1.7636 - val_accuracy: 0.5800
# Epoch 65/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.2240 - accuracy: 0.9098 - val_loss: 0.6618 - val_accuracy: 0.7625
# Epoch 66/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.2424 - accuracy: 0.9098 - val_loss: 1.6036 - val_accuracy: 0.6250
# Epoch 67/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.2770 - accuracy: 0.8954 - val_loss: 0.7779 - val_accuracy: 0.7050
# Epoch 68/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.2515 - accuracy: 0.8863 - val_loss: 0.6931 - val_accuracy: 0.7800
# Epoch 69/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.1825 - accuracy: 0.9190 - val_loss: 1.0359 - val_accuracy: 0.7175
# Epoch 70/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.2366 - accuracy: 0.9072 - val_loss: 1.2669 - val_accuracy: 0.7075
# Epoch 71/100
# 24/24 [==============================] - 4s 126ms/step - loss: 0.1806 - accuracy: 0.9307 - val_loss: 1.4767 - val_accuracy: 0.6550
# Epoch 72/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1707 - accuracy: 0.9333 - val_loss: 2.8815 - val_accuracy: 0.6425
# Epoch 73/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.2417 - accuracy: 0.9190 - val_loss: 1.1043 - val_accuracy: 0.6750
# Epoch 74/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.2513 - accuracy: 0.9059 - val_loss: 1.1800 - val_accuracy: 0.6900
# Epoch 75/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.2012 - accuracy: 0.9320 - val_loss: 1.2691 - val_accuracy: 0.6300
# Epoch 76/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.1562 - accuracy: 0.9399 - val_loss: 0.8493 - val_accuracy: 0.7350
# Epoch 77/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.1666 - accuracy: 0.9386 - val_loss: 1.7520 - val_accuracy: 0.6225
# Epoch 78/100
# 24/24 [==============================] - 3s 126ms/step - loss: 0.1365 - accuracy: 0.9425 - val_loss: 2.2006 - val_accuracy: 0.6525
# Epoch 79/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1426 - accuracy: 0.9490 - val_loss: 7.1585 - val_accuracy: 0.5475
# Epoch 80/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.1594 - accuracy: 0.9373 - val_loss: 1.2261 - val_accuracy: 0.6525
# Epoch 81/100
# 24/24 [==============================] - 3s 125ms/step - loss: 0.1542 - accuracy: 0.9464 - val_loss: 4.3055 - val_accuracy: 0.5400
# Epoch 82/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.1842 - accuracy: 0.9216 - val_loss: 1.8088 - val_accuracy: 0.6775
# Epoch 83/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.1052 - accuracy: 0.9582 - val_loss: 2.0935 - val_accuracy: 0.7025
# Epoch 84/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.1189 - accuracy: 0.9542 - val_loss: 1.3312 - val_accuracy: 0.7475
# Epoch 85/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1086 - accuracy: 0.9647 - val_loss: 2.4442 - val_accuracy: 0.6375
# Epoch 86/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1319 - accuracy: 0.9464 - val_loss: 4.1971 - val_accuracy: 0.5875
# Epoch 87/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1071 - accuracy: 0.9556 - val_loss: 2.8856 - val_accuracy: 0.6650
# Epoch 88/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.1789 - accuracy: 0.9333 - val_loss: 3.2483 - val_accuracy: 0.6575
# Epoch 89/100
# 24/24 [==============================] - 4s 133ms/step - loss: 0.0931 - accuracy: 0.9621 - val_loss: 1.4603 - val_accuracy: 0.7350
# Epoch 90/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.1147 - accuracy: 0.9569 - val_loss: 2.7374 - val_accuracy: 0.5950
# Epoch 91/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.1138 - accuracy: 0.9595 - val_loss: 1.0496 - val_accuracy: 0.7550
# Epoch 92/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.1196 - accuracy: 0.9556 - val_loss: 1.0278 - val_accuracy: 0.7600
# Epoch 93/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.1156 - accuracy: 0.9621 - val_loss: 1.2083 - val_accuracy: 0.7425
# Epoch 94/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.1269 - accuracy: 0.9569 - val_loss: 2.3137 - val_accuracy: 0.7275
# Epoch 95/100
# 24/24 [==============================] - 4s 132ms/step - loss: 0.0741 - accuracy: 0.9725 - val_loss: 1.2305 - val_accuracy: 0.7575
# Epoch 96/100
# 24/24 [==============================] - 4s 129ms/step - loss: 0.1856 - accuracy: 0.9373 - val_loss: 1.1713 - val_accuracy: 0.7450
# Epoch 97/100
# 24/24 [==============================] - 4s 130ms/step - loss: 0.0743 - accuracy: 0.9765 - val_loss: 3.3791 - val_accuracy: 0.6225
# Epoch 98/100
# 24/24 [==============================] - 4s 127ms/step - loss: 0.1361 - accuracy: 0.9490 - val_loss: 1.7559 - val_accuracy: 0.6925
# Epoch 99/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.0649 - accuracy: 0.9817 - val_loss: 1.3589 - val_accuracy: 0.6875
# Epoch 100/100
# 24/24 [==============================] - 4s 128ms/step - loss: 0.0605 - accuracy: 0.9765 - val_loss: 2.0887 - val_accuracy: 0.7250

# %% [markdown]
# And we can plot loss over training iterations...

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'],c="b")
plt.plot(history.history['accuracy'],c="r")
plt.legend(['Validation Acc','Training Acc'])
plt.show()

# %% [markdown]
# Note that we can now reach ~70% accuracy with 100 epochs of learning...

# %%
test_model = keras.models.load_model("Xception.keras")
test_loss, test_acc = test_model.evaluate(test_dataset) 
print(f"Test accuracy: {test_acc}")
# Out:
# 25/25 [==============================] - 96s 3s/step - loss: 0.6834 - accuracy: 0.6917
# Test accuracy: 0.6917293071746826
